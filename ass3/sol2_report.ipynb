# %% [markdown]
# ### This is the report for motion estimation using iterative PnP.

# %% [markdown]
# Formulation of cost function for Gauss newton optimization:
#
# ![first-udit.jpg](attachment:first-udit.jpg)
# ![udit-2.jpg](attachment:udit-2.jpg)
# ![udit-3.jpg](attachment:udit-3.jpg)
# ![udit-4.jpg](attachment:udit-4.jpg)
# ![udit-5.jpg](attachment:udit-5.jpg)

# %% [markdown]
# Image taken of 3d point cloud. Larger coordinate axis is world, while smaller is camera.
#
# ![open3d_camera.png](attachment:open3d_camera.png)

# %% [markdown]
# Original P matrix:
# ``` [[    525.        0.      319.5 -691575. ]
#      [      0.      525.      239.5  -98575. ]
#      [      0.        0.        1.     -850. ]] ```

# %% [markdown]
# Image taken using original P matrix:
#
# ![Poriginal.png](attachment:Poriginal.png)

# %% [markdown]
# Noisy P matrix:
# ```[[    525.26       0.47     319.88 -691574.86]
#     [      0.11     525.34     239.58  -98574.8 ]
#     [      0.31       0.21       1.      -849.56]] ```
#
# Frobenius norm between P_original and P_noisy: ```0.982969```
# Frobenius norm between RTOrig and RTNoise is: 0.724716

# %% [markdown]
# Image taken using noisy P matrix:
# ![PNoise.png](attachment:PNoise.png)

# %% [markdown]
# Frobenius norm between JNum and JAnaly is: 0.000000

# %% [markdown]
# Reprojection step during Gauss Newton step is given by:
# ```Reprojection error: 675.364497
# Reprojection error: 85.396653
# Reprojection error: 3.391452
# Reprojection error: 0.009977```

# %% [markdown]
# Optimized P using gauss newton step:
# ```[[    525.06       0.47     319.47 -691574.84]
#  [      0.       525.34     239.5   -98574.95]
#  [      0.         0.21       1.      -850.01]]```

# %% [markdown]
# Frobenius norm between POrig and POpt is: 0.645742
# Frobenius norm between RTOrig and RTOpt is: 0.258292

# %% [markdown]
# Original RT:
# ```[[   1.    0.    0. -800.]
#  [   0.    1.    0.  200.]
#  [   0.    0.    1. -850.]]```
# Optimized RT:
# ```[[   1.     -0.12   -0.   -799.99]
#  [  -0.      0.91    0.    200.  ]
#  [   0.      0.21    1.   -850.01]]```

# %% [markdown]
# Image taken using optimized P matrix:
# ![POpt.png](attachment:POpt.png)

# %% [markdown]
# Enforcing SO(3) condition on R matrix:
# ```[[   1.     -0.06    0.   -799.99]
#  [   0.06    0.99   -0.11  200.  ]
#  [   0.      0.11    0.99 -850.01]]```
