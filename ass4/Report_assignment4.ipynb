# %% [markdown]
# ## EKF Steps and Measurement and Sensor Model
#
# ![steps_model.jpg](attachment:steps_model.jpg)

# %% [markdown]
# ## Deriving Jacobian F<sub>k-1</sub> (Motion Model)
#
# ![Fkminus1.jpg](attachment:Fkminus1.jpg)

# %% [markdown]
# ## Deriving Jacobian G<sub>k</sub> (Measurement Model)
#
# ![Gk.jpg](attachment:Gk.jpg)

# %% [markdown]
# ## Deriving Modified Covariance Q'<sub>k</sub> for Process Noise.
# 1. The nonlinearity in process noise is also taken into account.
#
# ![Qk'.jpg](attachment:Qk'.jpg)

# %% [markdown]
# ## Deriving Modified Covariance Q'<sub>k</sub> for Sensor Noise.
# 1. The nonlinearity in sensor noise is also taken into account.
#
# ![Rk'.jpg](attachment:Rk'.jpg)

# %% [markdown]
# ## Implementation
#
# 1. Corresponding code is in the python file: `sol1.py`
# 2. EKF with multiple landmarks along with implementation of jacobians and covariances is done.
# 3. We only used the closest landmark to update the robot position as it is giving good trajectory comparison to using all landmarks for updating.

# %% [markdown]
# ## Results
#
# 1. GroundTruth versus Noisy Trajectory. Groundtruth is shown in red trajectory while blue is the noisy trajectory. Green stars are landmarks location.
#
# ![gt_vs_noisy.png](attachment:gt_vs_noisy.png)
#
#
# 2. GroundTruth versus EKF Trajectory. Groundtruth is shown in red trajectory while blue is the EKF trajectory. Green stars are landmarks location.
#
# ![gt_vs_ekf.png](attachment:gt_vs_ekf.png)
